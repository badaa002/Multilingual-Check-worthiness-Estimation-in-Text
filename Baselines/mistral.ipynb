# %%
from ollama import Client, Options
from typing import Dict, Any, List
import yaml
import re
import os
from torch import Tensor
import pandas as pd

# %%
CHECKWORTHY_PROMPT = """Given a sentence from a political debate or tweet, your task is to predict if it is fact check-worthy statement or not.
 Your response must always start with "My response is: (yes or no based on your prediction)"
 your prediction must be yes or no, and i wont accept you prediction to be "I cannot determine"
 Never write "I'm and AI language model..."

 Sentence: {claim}"""

# %%
class Ollama:
    """A class for generating questions and interacting with the Ollama API."""

    def __init__(self, config_path: str = "mistral.yaml"):
        """Initializes the Ollama client and loads necessary configurations."""
        self._ollama_client = Client(timeout=20)
        self._config_path = config_path
        self._config = self._load_config()
        self._stream = self._config.get("stream", False)
        self._model_name = self._config.get("model", "mistral")
        self._llm_options = self._get_llm_config()

    def generate(self, prompt: str) -> str:
        """Generate text using Ollama LLM for the given prompt.

        Args:
            prompt: Prompt for the LLM.

        Returns:
            Response text from an Ollama LLM.
        """
        response = self._ollama_client.generate(
            model=self._model_name,
            prompt=prompt,
            options=self._llm_options,
            stream=self._stream,
        )
        return response.get("response", "").strip()  # type: ignore

    def _load_config(self) -> Dict[str, Any]:
        """Loads configuration from a YAML file.

        Raises:
            FileNotFoundError: If the config file is not found.

        Returns:
            A dictionary with configuration values.
        """
        if not os.path.isfile(self._config_path):
            raise FileNotFoundError(
                f"Config file {self._config_path} not found."
            )
        with open(self._config_path, "r") as file:
            yaml_data = yaml.safe_load(file)
        return yaml_data

    def _get_llm_config(self) -> Options:
        """Extracts and returns the LLM (language learning model) configuration.

        Returns:
            An Options object with the LLM configuration.
        """
        return Options(self._config.get("options", {}))

# %%
ollama = Ollama()

# %%
listofpredicts = list()
similarity = 0
df = pd.read_csv('../data/processed/processed_dev_test.tsv', sep='\t')
for index, row in df.iterrows():
    response = ollama.generate(CHECKWORTHY_PROMPT.format(claim=row['text']))
    response_words = response.split()
    answer = response_words[3].strip('.,').lower()
    if answer == "yes" or answer == "no":
        listofpredicts.append(response_words[3].strip('.').lower())
    else:
        listofpredicts.append("no")
# Out:
# My response is: No. This sentence does not contain a fact-check worthy statement. It is grammatically incorrect and does not make a clear claim that can be fact-checked.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'fact-check', 'worthy', 'statement.', 'It', 'is', 'grammatically', 'incorrect', 'and', 'does', 'not', 'make', 'a', 'clear', 'claim', 'that', 'can', 'be', 'fact-checked.']
# My response is: No. This sentence does not contain a factual claim that can be checked.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.']
# My response is: yes. This statement implies a potential gender-based price discrimination, which is fact check-worthy.
# ['My', 'response', 'is:', 'yes.', 'This', 'statement', 'implies', 'a', 'potential', 'gender-based', 'price', 'discrimination,', 'which', 'is', 'fact', 'check-worthy.']
# My response is: no. This statement does not contain any factual claim that can be checked. It is a subjective expression of opinion about the extent to which people have been given an opportunity to express themselves.
# ['My', 'response', 'is:', 'no.', 'This', 'statement', 'does', 'not', 'contain', 'any', 'factual', 'claim', 'that', 'can', 'be', 'checked.', 'It', 'is', 'a', 'subjective', 'expression', 'of', 'opinion', 'about', 'the', 'extent', 'to', 'which', 'people', 'have', 'been', 'given', 'an', 'opportunity', 'to', 'express', 'themselves.']
# My response is: No. This sentence does not contain a factual claim that can be checked. It is a statement of identity, not an assertion about the world that can be verified or falsified.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.', 'It', 'is', 'a', 'statement', 'of', 'identity,', 'not', 'an', 'assertion', 'about', 'the', 'world', 'that', 'can', 'be', 'verified', 'or', 'falsified.']
# My response is: yes. The sentence seems to be stating a potential number of people who have contracted COVID-19, which is a factual claim that could be checked for accuracy.
# ['My', 'response', 'is:', 'yes.', 'The', 'sentence', 'seems', 'to', 'be', 'stating', 'a', 'potential', 'number', 'of', 'people', 'who', 'have', 'contracted', 'COVID-19,', 'which', 'is', 'a', 'factual', 'claim', 'that', 'could', 'be', 'checked', 'for', 'accuracy.']
# My response is: no. This sentence does not contain a factual claim that can be checked.
# ['My', 'response', 'is:', 'no.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.']
# My response is: No. This sentence does not contain a factual statement that can be checked. It is a declaration of willingness to discuss something.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'statement', 'that', 'can', 'be', 'checked.', 'It', 'is', 'a', 'declaration', 'of', 'willingness', 'to', 'discuss', 'something.']
# My response is: No. This sentence appears to be grammatically incorrect and does not contain a factual claim that can be checked.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'appears', 'to', 'be', 'grammatically', 'incorrect', 'and', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.']
# My response is: No. This sentence appears to be incomplete and does not contain a factual statement.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'appears', 'to', 'be', 'incomplete', 'and', 'does', 'not', 'contain', 'a', 'factual', 'statement.']
# My response is: I cannot understand this sentence without additional context. It seems to be incomplete or misspelled. Therefore, I cannot determine if it is fact check-worthy.
# ['My', 'response', 'is:', 'I', 'cannot', 'understand', 'this', 'sentence', 'without', 'additional', 'context.', 'It', 'seems', 'to', 'be', 'incomplete', 'or', 'misspelled.', 'Therefore,', 'I', 'cannot', 'determine', 'if', 'it', 'is', 'fact', 'check-worthy.']
# My response is: I cannot understand this sentence without additional context. It seems to be incomplete or misspelled. Therefore, I cannot determine if it is fact check-worthy.
# i
#
# My response is: Yes, this statement does not necessarily contain a factual claim that needs to be checked, but it is a promise or intention statement which can be fact-checked in the future based on actions taken.
# ['My', 'response', 'is:', 'Yes,', 'this', 'statement', 'does', 'not', 'necessarily', 'contain', 'a', 'factual', 'claim', 'that', 'needs', 'to', 'be', 'checked,', 'but', 'it', 'is', 'a', 'promise', 'or', 'intention', 'statement', 'which', 'can', 'be', 'fact-checked', 'in', 'the', 'future', 'based', 'on', 'actions', 'taken.']
# My response is: Yes, if the example given in the sentence contains a potential factual claim that could be checked for accuracy.
# ['My', 'response', 'is:', 'Yes,', 'if', 'the', 'example', 'given', 'in', 'the', 'sentence', 'contains', 'a', 'potential', 'factual', 'claim', 'that', 'could', 'be', 'checked', 'for', 'accuracy.']
# My response is: no. This sentence appears to be incomplete and grammatically incorrect, making it difficult to determine if it contains a factual statement or not.
# ['My', 'response', 'is:', 'no.', 'This', 'sentence', 'appears', 'to', 'be', 'incomplete', 'and', 'grammatically', 'incorrect,', 'making', 'it', 'difficult', 'to', 'determine', 'if', 'it', 'contains', 'a', 'factual', 'statement', 'or', 'not.']
# My response is: No. The term "Super Tuesday" refers to a day in the primary election process when multiple states hold their primaries or caucuses. It is not an event that bestows luck upon any particular candidate.
# ['My', 'response', 'is:', 'No.', 'The', 'term', '"Super', 'Tuesday"', 'refers', 'to', 'a', 'day', 'in', 'the', 'primary', 'election', 'process', 'when', 'multiple', 'states', 'hold', 'their', 'primaries', 'or', 'caucuses.', 'It', 'is', 'not', 'an', 'event', 'that', 'bestows', 'luck', 'upon', 'any', 'particular', 'candidate.']
# My response is: No. This sentence appears to be incomplete and grammatically incorrect, making it difficult to determine if it contains a factual claim that could be checkable.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'appears', 'to', 'be', 'incomplete', 'and', 'grammatically', 'incorrect,', 'making', 'it', 'difficult', 'to', 'determine', 'if', 'it', 'contains', 'a', 'factual', 'claim', 'that', 'could', 'be', 'checkable.']
# My response is: No. This sentence does not contain a factual statement that can be checked. It appears to simply mean "this is the situation" or "let me explain," but it does not make a claim that can be verified or falsified.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'statement', 'that', 'can', 'be', 'checked.', 'It', 'appears', 'to', 'simply', 'mean', '"this', 'is', 'the', 'situation"', 'or', '"let', 'me', 'explain,"', 'but', 'it', 'does', 'not', 'make', 'a', 'claim', 'that', 'can', 'be', 'verified', 'or', 'falsified.']
# My response is: yes. This statement implies that all the things mentioned by a person have been identified as lies, making it fact-check worthy.
# ['My', 'response', 'is:', 'yes.', 'This', 'statement', 'implies', 'that', 'all', 'the', 'things', 'mentioned', 'by', 'a', 'person', 'have', 'been', 'identified', 'as', 'lies,', 'making', 'it', 'fact-check', 'worthy.']
# My response is: No. This sentence does not contain a factual claim that can be checked. It appears to be a figure of speech or metaphor, and does not provide enough specific information to be fact-checked.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.', 'It', 'appears', 'to', 'be', 'a', 'figure', 'of', 'speech', 'or', 'metaphor,', 'and', 'does', 'not', 'provide', 'enough', 'specific', 'information', 'to', 'be', 'fact-checked.']
# My response is: yes. The sentence implies that there exists a specific plan agreed upon by the speaker and Bernie Sanders, which is being labeled as "socialize medicine" by others. This statement could potentially be fact-checked to determine the accuracy of this label and whether or not it accurately reflects the contents of the plan.
# ['My', 'response', 'is:', 'yes.', 'The', 'sentence', 'implies', 'that', 'there', 'exists', 'a', 'specific', 'plan', 'agreed', 'upon', 'by', 'the', 'speaker', 'and', 'Bernie', 'Sanders,', 'which', 'is', 'being', 'labeled', 'as', '"socialize', 'medicine"', 'by', 'others.', 'This', 'statement', 'could', 'potentially', 'be', 'fact-checked', 'to', 'determine', 'the', 'accuracy', 'of', 'this', 'label', 'and', 'whether', 'or', 'not', 'it', 'accurately', 'reflects', 'the', 'contents', 'of', 'the', 'plan.']
# My response is: yes (assuming the subject of "he" is a specific person and the verb tense implies past actions, making it potentially fact-check worthy to determine if they have or haven't offered a plan in the past)
# ['My', 'response', 'is:', 'yes', '(assuming', 'the', 'subject', 'of', '"he"', 'is', 'a', 'specific', 'person', 'and', 'the', 'verb', 'tense', 'implies', 'past', 'actions,', 'making', 'it', 'potentially', 'fact-check', 'worthy', 'to', 'determine', 'if', 'they', 'have', 'or', "haven't", 'offered', 'a', 'plan', 'in', 'the', 'past)']
# My response is: yes, that statement could be fact-check worthy depending on the context in which it is being used. For example, if the speaker is discussing a specific piece of legislation, then the accuracy of their statement would depend on whether or not the individual mandate has been taken away in that context. If the speaker is making a broader statement about healthcare policy, then the fact-check would depend on whether or not they are accurately describing the current state of affairs regarding the individual mandate
# ['My', 'response', 'is:', 'yes,', 'that', 'statement', 'could', 'be', 'fact-check', 'worthy', 'depending', 'on', 'the', 'context', 'in', 'which', 'it', 'is', 'being', 'used.', 'For', 'example,', 'if', 'the', 'speaker', 'is', 'discussing', 'a', 'specific', 'piece', 'of', 'legislation,', 'then', 'the', 'accuracy', 'of', 'their', 'statement', 'would', 'depend', 'on', 'whether', 'or', 'not', 'the', 'individual', 'mandate', 'has', 'been', 'taken', 'away', 'in', 'that', 'context.', 'If', 'the', 'speaker', 'is', 'making', 'a', 'broader', 'statement', 'about', 'healthcare', 'policy,', 'then', 'the', 'fact-check', 'would', 'depend', 'on', 'whether', 'or', 'not', 'they', 'are', 'accurately', 'describing', 'the', 'current', 'state', 'of', 'affairs', 'regarding', 'the', 'individual', 'mandate']
# My response is: yes. This statement seems to be making a comparison between two different policies, one of which (guaranteeing preexisting conditions) is a requirement under the Affordable Care Act, while the other (taking away the individual mandate) was a provision of that same law. The accuracy of this statement would depend on the specific context in which it was made and what exactly is meant by "we guarantee" in this context. However, the statement itself implies a
# ['My', 'response', 'is:', 'yes.', 'This', 'statement', 'seems', 'to', 'be', 'making', 'a', 'comparison', 'between', 'two', 'different', 'policies,', 'one', 'of', 'which', '(guaranteeing', 'preexisting', 'conditions)', 'is', 'a', 'requirement', 'under', 'the', 'Affordable', 'Care', 'Act,', 'while', 'the', 'other', '(taking', 'away', 'the', 'individual', 'mandate)', 'was', 'a', 'provision', 'of', 'that', 'same', 'law.', 'The', 'accuracy', 'of', 'this', 'statement', 'would', 'depend', 'on', 'the', 'specific', 'context', 'in', 'which', 'it', 'was', 'made', 'and', 'what', 'exactly', 'is', 'meant', 'by', '"we', 'guarantee"', 'in', 'this', 'context.', 'However,', 'the', 'statement', 'itself', 'implies', 'a']
# My response is: No. This sentence does not contain a factual claim that can be checked. It is a hypothetical statement about potential blame in the future.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.', 'It', 'is', 'a', 'hypothetical', 'statement', 'about', 'potential', 'blame', 'in', 'the', 'future.']
# My response is: Yes, this statement does not contain any factual claims that can be checked or false. It is a statement of intent from the speaker.
# ['My', 'response', 'is:', 'Yes,', 'this', 'statement', 'does', 'not', 'contain', 'any', 'factual', 'claims', 'that', 'can', 'be', 'checked', 'or', 'false.', 'It', 'is', 'a', 'statement', 'of', 'intent', 'from', 'the', 'speaker.']
# My response is: Yes, the sentence could be fact-check worthy depending on the context. Without additional information, it is unclear what "it" refers to.
# ['My', 'response', 'is:', 'Yes,', 'the', 'sentence', 'could', 'be', 'fact-check', 'worthy', 'depending', 'on', 'the', 'context.', 'Without', 'additional', 'information,', 'it', 'is', 'unclear', 'what', '"it"', 'refers', 'to.']
# My response is: no. This sentence appears to be grammatically incorrect and does not contain a factual claim that can be checked.
# ['My', 'response', 'is:', 'no.', 'This', 'sentence', 'appears', 'to', 'be', 'grammatically', 'incorrect', 'and', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.']
# My response is: no. This sentence does not contain a factual claim that can be checked. It is a statement about the speaker's perspective and does not make a statement that can be verified or falsified.
# ['My', 'response', 'is:', 'no.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.', 'It', 'is', 'a', 'statement', 'about', 'the', "speaker's", 'perspective', 'and', 'does', 'not', 'make', 'a', 'statement', 'that', 'can', 'be', 'verified', 'or', 'falsified.']
# My response is: No. This sentence does not contain a factual claim that can be checked. It appears to be a fragment of a sentence and does not make any clear statement about an issue or the American people.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.', 'It', 'appears', 'to', 'be', 'a', 'fragment', 'of', 'a', 'sentence', 'and', 'does', 'not', 'make', 'any', 'clear', 'statement', 'about', 'an', 'issue', 'or', 'the', 'American', 'people.']
# My response is: No. The sentence does not contain a factual claim that can be checked.
# ['My', 'response', 'is:', 'No.', 'The', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.']
# My response is: No. This sentence does not contain a fact-check worthy statement.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'fact-check', 'worthy', 'statement.']
# My response is: No. This sentence does not contain a factual claim that can be checked. It appears to be a fragment of speech, possibly asking who is on someone else's list, but it does not provide enough information to be fact-checked.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.', 'It', 'appears', 'to', 'be', 'a', 'fragment', 'of', 'speech,', 'possibly', 'asking', 'who', 'is', 'on', 'someone', "else's", 'list,', 'but', 'it', 'does', 'not', 'provide', 'enough', 'information', 'to', 'be', 'fact-checked.']
# My response is: no. The sentence appears to be incomplete and contains grammatical errors, making it difficult to determine if the statement is factual or not. Additionally, it seems to be missing crucial information needed for a fact check.
# ['My', 'response', 'is:', 'no.', 'The', 'sentence', 'appears', 'to', 'be', 'incomplete', 'and', 'contains', 'grammatical', 'errors,', 'making', 'it', 'difficult', 'to', 'determine', 'if', 'the', 'statement', 'is', 'factual', 'or', 'not.', 'Additionally,', 'it', 'seems', 'to', 'be', 'missing', 'crucial', 'information', 'needed', 'for', 'a', 'fact', 'check.']
# My response is: Yes. This statement could potentially be fact-check worthy as it makes a claim about the number of people contracting COVID-19 per day.
# ['My', 'response', 'is:', 'Yes.', 'This', 'statement', 'could', 'potentially', 'be', 'fact-check', 'worthy', 'as', 'it', 'makes', 'a', 'claim', 'about', 'the', 'number', 'of', 'people', 'contracting', 'COVID-19', 'per', 'day.']
# My response is: No. This sentence does not contain a factual statement that can be checked. It appears to be a colloquial expression with no clear meaning or verifiable information.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'statement', 'that', 'can', 'be', 'checked.', 'It', 'appears', 'to', 'be', 'a', 'colloquial', 'expression', 'with', 'no', 'clear', 'meaning', 'or', 'verifiable', 'information.']
# My response is: Yes, this sentence could be fact-check worthy depending on the context. It seems incomplete and could potentially be misleading if taken out of context. For example, it could be asking about a specific action taken by someone, or it could be a rhetorical question. Without additional context, it's difficult to determine for certain. However, if this sentence is being used to make a factual claim, then it could be worth checking for accuracy.
# ['My', 'response', 'is:', 'Yes,', 'this', 'sentence', 'could', 'be', 'fact-check', 'worthy', 'depending', 'on', 'the', 'context.', 'It', 'seems', 'incomplete', 'and', 'could', 'potentially', 'be', 'misleading', 'if', 'taken', 'out', 'of', 'context.', 'For', 'example,', 'it', 'could', 'be', 'asking', 'about', 'a', 'specific', 'action', 'taken', 'by', 'someone,', 'or', 'it', 'could', 'be', 'a', 'rhetorical', 'question.', 'Without', 'additional', 'context,', "it's", 'difficult', 'to', 'determine', 'for', 'certain.', 'However,', 'if', 'this', 'sentence', 'is', 'being', 'used', 'to', 'make', 'a', 'factual', 'claim,', 'then', 'it', 'could', 'be', 'worth', 'checking', 'for', 'accuracy.']
# My response is: Yes, this sentence may be fact-check worthy depending on the context in which it was used during a political debate or tweet. The ambiguity of the sentence makes it unclear who "he" refers to and what actions are being described, which could potentially lead to misinformation or confusion.
# ['My', 'response', 'is:', 'Yes,', 'this', 'sentence', 'may', 'be', 'fact-check', 'worthy', 'depending', 'on', 'the', 'context', 'in', 'which', 'it', 'was', 'used', 'during', 'a', 'political', 'debate', 'or', 'tweet.', 'The', 'ambiguity', 'of', 'the', 'sentence', 'makes', 'it', 'unclear', 'who', '"he"', 'refers', 'to', 'and', 'what', 'actions', 'are', 'being', 'described,', 'which', 'could', 'potentially', 'lead', 'to', 'misinformation', 'or', 'confusion.']
# My response is: No. This sentence does not contain a factual claim that can be checked. It appears to be a fragmented statement about an action or belief, but it does not contain any specific information that can be verified or falsified.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.', 'It', 'appears', 'to', 'be', 'a', 'fragmented', 'statement', 'about', 'an', 'action', 'or', 'belief,', 'but', 'it', 'does', 'not', 'contain', 'any', 'specific', 'information', 'that', 'can', 'be', 'verified', 'or', 'falsified.']
# My response is: Yes, this sentence could be fact-check worthy as it is unclear what the speaker intends to mean by "and I lie out again in July what we should be do." It could potentially contain inaccuracies or misstatements.
# ['My', 'response', 'is:', 'Yes,', 'this', 'sentence', 'could', 'be', 'fact-check', 'worthy', 'as', 'it', 'is', 'unclear', 'what', 'the', 'speaker', 'intends', 'to', 'mean', 'by', '"and', 'I', 'lie', 'out', 'again', 'in', 'July', 'what', 'we', 'should', 'be', 'do."', 'It', 'could', 'potentially', 'contain', 'inaccuracies', 'or', 'misstatements.']
# My response is: Yes, this statement does not contain any verifiable factual information and is more of a suggestion or recommendation, making it potentially fact-check worthy depending on the context in which it is made.
# ['My', 'response', 'is:', 'Yes,', 'this', 'statement', 'does', 'not', 'contain', 'any', 'verifiable', 'factual', 'information', 'and', 'is', 'more', 'of', 'a', 'suggestion', 'or', 'recommendation,', 'making', 'it', 'potentially', 'fact-check', 'worthy', 'depending', 'on', 'the', 'context', 'in', 'which', 'it', 'is', 'made.']
# My response is: no, this statement does not necessarily need to be fact-checked as it is an expression of opinion and not a factual claim. However, if the context suggests that specific Democrat Governors have made such statements on the record, then fact-checking could be warranted to verify the accuracy of their quotes.
# ['My', 'response', 'is:', 'no,', 'this', 'statement', 'does', 'not', 'necessarily', 'need', 'to', 'be', 'fact-checked', 'as', 'it', 'is', 'an', 'expression', 'of', 'opinion', 'and', 'not', 'a', 'factual', 'claim.', 'However,', 'if', 'the', 'context', 'suggests', 'that', 'specific', 'Democrat', 'Governors', 'have', 'made', 'such', 'statements', 'on', 'the', 'record,', 'then', 'fact-checking', 'could', 'be', 'warranted', 'to', 'verify', 'the', 'accuracy', 'of', 'their', 'quotes.']
# My response is: no. This sentence does not make a factual statement that can be checked. It appears to contain a typo or grammatical error.
# ['My', 'response', 'is:', 'no.', 'This', 'sentence', 'does', 'not', 'make', 'a', 'factual', 'statement', 'that', 'can', 'be', 'checked.', 'It', 'appears', 'to', 'contain', 'a', 'typo', 'or', 'grammatical', 'error.']
# My response is: I cannot evaluate the truthfulness of that statement as it is incomplete and subjective. The term "we" is not clearly defined, and the phrase "have done a great job" is open to interpretation.
# ['My', 'response', 'is:', 'I', 'cannot', 'evaluate', 'the', 'truthfulness', 'of', 'that', 'statement', 'as', 'it', 'is', 'incomplete', 'and', 'subjective.', 'The', 'term', '"we"', 'is', 'not', 'clearly', 'defined,', 'and', 'the', 'phrase', '"have', 'done', 'a', 'great', 'job"', 'is', 'open', 'to', 'interpretation.']
# My response is: I cannot evaluate the truthfulness of that statement as it is incomplete and subjective. The term "we" is not clearly defined, and the phrase "have done a great job" is open to interpretation.
# i
#
# My response is: no. This statement does not contain a factual claim that can be checked. It is an expression of opinion and does not make a statement that can be verified or falsified.
# ['My', 'response', 'is:', 'no.', 'This', 'statement', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.', 'It', 'is', 'an', 'expression', 'of', 'opinion', 'and', 'does', 'not', 'make', 'a', 'statement', 'that', 'can', 'be', 'verified', 'or', 'falsified.']
# My response is: yes. This statement implies that some people have experienced a loss due to COVID-19, and it is fact check-worthy to determine the accuracy of the number or percentage of people this applies to.
# ['My', 'response', 'is:', 'yes.', 'This', 'statement', 'implies', 'that', 'some', 'people', 'have', 'experienced', 'a', 'loss', 'due', 'to', 'COVID-19,', 'and', 'it', 'is', 'fact', 'check-worthy', 'to', 'determine', 'the', 'accuracy', 'of', 'the', 'number', 'or', 'percentage', 'of', 'people', 'this', 'applies', 'to.']
# My response is: yes. This statement describes a hypothetical situation that could potentially involve factual inaccuracies or exaggerations, depending on the context in which it was made. For example, the number of people who have experienced this situation is not specified, and the details of what exactly happened in each case are not provided. Therefore, fact-checking this statement would involve investigating the specific instances being referred to, and verifying that they indeed occurred as described.
# ['My', 'response', 'is:', 'yes.', 'This', 'statement', 'describes', 'a', 'hypothetical', 'situation', 'that', 'could', 'potentially', 'involve', 'factual', 'inaccuracies', 'or', 'exaggerations,', 'depending', 'on', 'the', 'context', 'in', 'which', 'it', 'was', 'made.', 'For', 'example,', 'the', 'number', 'of', 'people', 'who', 'have', 'experienced', 'this', 'situation', 'is', 'not', 'specified,', 'and', 'the', 'details', 'of', 'what', 'exactly', 'happened', 'in', 'each', 'case', 'are', 'not', 'provided.', 'Therefore,', 'fact-checking', 'this', 'statement', 'would', 'involve', 'investigating', 'the', 'specific', 'instances', 'being', 'referred', 'to,', 'and', 'verifying', 'that', 'they', 'indeed', 'occurred', 'as', 'described.']
# My response is: I cannot provide a definitive answer without additional context. The sentence seems ambiguous and could potentially be fact check-worthy depending on the specific topic and information being discussed after "that".
# ['My', 'response', 'is:', 'I', 'cannot', 'provide', 'a', 'definitive', 'answer', 'without', 'additional', 'context.', 'The', 'sentence', 'seems', 'ambiguous', 'and', 'could', 'potentially', 'be', 'fact', 'check-worthy', 'depending', 'on', 'the', 'specific', 'topic', 'and', 'information', 'being', 'discussed', 'after', '"that".']
# My response is: I cannot provide a definitive answer without additional context. The sentence seems ambiguous and could potentially be fact check-worthy depending on the specific topic and information being discussed after "that".
# i
#
# My response is: no. This sentence appears to be incomplete and does not contain a factual statement that can be checked.
# ['My', 'response', 'is:', 'no.', 'This', 'sentence', 'appears', 'to', 'be', 'incomplete', 'and', 'does', 'not', 'contain', 'a', 'factual', 'statement', 'that', 'can', 'be', 'checked.']
# My response is: No. This sentence does not contain a factual claim that can be checked. It appears to simply be a phrase or idiomatic expression.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.', 'It', 'appears', 'to', 'simply', 'be', 'a', 'phrase', 'or', 'idiomatic', 'expression.']
# My response is: No, the sentence itself does not contain a fact-check worthy statement. It is just asking a question about the use of a word.
# ['My', 'response', 'is:', 'No,', 'the', 'sentence', 'itself', 'does', 'not', 'contain', 'a', 'fact-check', 'worthy', 'statement.', 'It', 'is', 'just', 'asking', 'a', 'question', 'about', 'the', 'use', 'of', 'a', 'word.']
# My response is: No. This sentence does not contain a factual statement that can be checked. It is a simple expression of anticipation or eagerness.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'statement', 'that', 'can', 'be', 'checked.', 'It', 'is', 'a', 'simple', 'expression', 'of', 'anticipation', 'or', 'eagerness.']
# My response is: Yes. The sentence "tell that to Nancy Pelosi" is often used in a confrontational or dismissive way, and it implies that the person being addressed believes Nancy Pelosi will not agree or understand their point of view. This type of statement can be fact-check worthy if it is being used to misrepresent or distort someone's position, especially in a political debate.
# ['My', 'response', 'is:', 'Yes.', 'The', 'sentence', '"tell', 'that', 'to', 'Nancy', 'Pelosi"', 'is', 'often', 'used', 'in', 'a', 'confrontational', 'or', 'dismissive', 'way,', 'and', 'it', 'implies', 'that', 'the', 'person', 'being', 'addressed', 'believes', 'Nancy', 'Pelosi', 'will', 'not', 'agree', 'or', 'understand', 'their', 'point', 'of', 'view.', 'This', 'type', 'of', 'statement', 'can', 'be', 'fact-check', 'worthy', 'if', 'it', 'is', 'being', 'used', 'to', 'misrepresent', 'or', 'distort', "someone's", 'position,', 'especially', 'in', 'a', 'political', 'debate.']
# My response is: No. This sentence does not contain a fact-check worthy statement. It is grammatically incorrect and does not make a claim that can be verified or falsified.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'fact-check', 'worthy', 'statement.', 'It', 'is', 'grammatically', 'incorrect', 'and', 'does', 'not', 'make', 'a', 'claim', 'that', 'can', 'be', 'verified', 'or', 'falsified.']
# My response is: Yes, that statement could be fact-check worthy depending on the context. For example, if it's referring to a specific person and their political position or statement, it could be fact-checked to determine if they have indeed expressed a desire to "shut down the country." However, without additional context it's difficult to determine the exact meaning of "shut down" in this sentence.
# ['My', 'response', 'is:', 'Yes,', 'that', 'statement', 'could', 'be', 'fact-check', 'worthy', 'depending', 'on', 'the', 'context.', 'For', 'example,', 'if', "it's", 'referring', 'to', 'a', 'specific', 'person', 'and', 'their', 'political', 'position', 'or', 'statement,', 'it', 'could', 'be', 'fact-checked', 'to', 'determine', 'if', 'they', 'have', 'indeed', 'expressed', 'a', 'desire', 'to', '"shut', 'down', 'the', 'country."', 'However,', 'without', 'additional', 'context', "it's", 'difficult', 'to', 'determine', 'the', 'exact', 'meaning', 'of', '"shut', 'down"', 'in', 'this', 'sentence.']
# My response is: Yes, a statement about potential harm or negative consequences to more people can be fact-check worthy.
# ['My', 'response', 'is:', 'Yes,', 'a', 'statement', 'about', 'potential', 'harm', 'or', 'negative', 'consequences', 'to', 'more', 'people', 'can', 'be', 'fact-check', 'worthy.']
# My response is: No. This sentence does not contain a factual claim that can be checked.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.']
# My response is: no. This statement does not contain a factual claim that can be checked. It is an expression of opinion and does not lend itself to fact-checking.
# ['My', 'response', 'is:', 'no.', 'This', 'statement', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.', 'It', 'is', 'an', 'expression', 'of', 'opinion', 'and', 'does', 'not', 'lend', 'itself', 'to', 'fact-checking.']
# My response is: Yes, if the sentence implies that Dr. Fauci has made contradictory statements on a particular issue, it could be fact-check worthy.
# ['My', 'response', 'is:', 'Yes,', 'if', 'the', 'sentence', 'implies', 'that', 'Dr.', 'Fauci', 'has', 'made', 'contradictory', 'statements', 'on', 'a', 'particular', 'issue,', 'it', 'could', 'be', 'fact-check', 'worthy.']
# My response is: yes. The sentence seems to be making a statement about someone's actions regarding social distancing and mask-wearing, which could potentially be fact checkable depending on the specifics of what is being claimed.
# ['My', 'response', 'is:', 'yes.', 'The', 'sentence', 'seems', 'to', 'be', 'making', 'a', 'statement', 'about', "someone's", 'actions', 'regarding', 'social', 'distancing', 'and', 'mask-wearing,', 'which', 'could', 'potentially', 'be', 'fact', 'checkable', 'depending', 'on', 'the', 'specifics', 'of', 'what', 'is', 'being', 'claimed.']
# My response is: I cannot parse this sentence into a clear statement that can be labeled as fact check-worthy or not. It seems to be incomplete and lacks a specific claim that can be fact-checked.
# ['My', 'response', 'is:', 'I', 'cannot', 'parse', 'this', 'sentence', 'into', 'a', 'clear', 'statement', 'that', 'can', 'be', 'labeled', 'as', 'fact', 'check-worthy', 'or', 'not.', 'It', 'seems', 'to', 'be', 'incomplete', 'and', 'lacks', 'a', 'specific', 'claim', 'that', 'can', 'be', 'fact-checked.']
# My response is: I cannot parse this sentence into a clear statement that can be labeled as fact check-worthy or not. It seems to be incomplete and lacks a specific claim that can be fact-checked.
# i
#
# My response is: No. This sentence does not contain a factual claim that can be checked. It appears to simply express a subjective opinion or thought.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.', 'It', 'appears', 'to', 'simply', 'express', 'a', 'subjective', 'opinion', 'or', 'thought.']
# My response is: Yes. The sentence seems to be making a comparison or statement about divorce, alcoholism, and drugs without providing clear context or facts. This type of statement is often fact-check worthy.
# ['My', 'response', 'is:', 'Yes.', 'The', 'sentence', 'seems', 'to', 'be', 'making', 'a', 'comparison', 'or', 'statement', 'about', 'divorce,', 'alcoholism,', 'and', 'drugs', 'without', 'providing', 'clear', 'context', 'or', 'facts.', 'This', 'type', 'of', 'statement', 'is', 'often', 'fact-check', 'worthy.']
# My response is: no. This sentence does not contain a fact-check worthy statement. It is simply describing an action taken by "this guy" and does not make a claim that can be verified or falsified.
# ['My', 'response', 'is:', 'no.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'fact-check', 'worthy', 'statement.', 'It', 'is', 'simply', 'describing', 'an', 'action', 'taken', 'by', '"this', 'guy"', 'and', 'does', 'not', 'make', 'a', 'claim', 'that', 'can', 'be', 'verified', 'or', 'falsified.']
# My response is: yes. The sentence seems to be making a factual claim about the number of jobs in the president's administration before and after they took office.
# ['My', 'response', 'is:', 'yes.', 'The', 'sentence', 'seems', 'to', 'be', 'making', 'a', 'factual', 'claim', 'about', 'the', 'number', 'of', 'jobs', 'in', 'the', "president's", 'administration', 'before', 'and', 'after', 'they', 'took', 'office.']
# My response is: I cannot understand the complete meaning of this sentence without additional context, so I cannot make a fact-check worthy prediction. However, if this sentence is intended to mean that opening something safely costs a lot of money, then my response would be: yes.
# ['My', 'response', 'is:', 'I', 'cannot', 'understand', 'the', 'complete', 'meaning', 'of', 'this', 'sentence', 'without', 'additional', 'context,', 'so', 'I', 'cannot', 'make', 'a', 'fact-check', 'worthy', 'prediction.', 'However,', 'if', 'this', 'sentence', 'is', 'intended', 'to', 'mean', 'that', 'opening', 'something', 'safely', 'costs', 'a', 'lot', 'of', 'money,', 'then', 'my', 'response', 'would', 'be:', 'yes.']
# My response is: I cannot understand the complete meaning of this sentence without additional context, so I cannot make a fact-check worthy prediction. However, if this sentence is intended to mean that opening something safely costs a lot of money, then my response would be: yes.
# i
#
# My response is: No. The sentence does not contain a clear and complete statement for fact-checking purposes.
# ['My', 'response', 'is:', 'No.', 'The', 'sentence', 'does', 'not', 'contain', 'a', 'clear', 'and', 'complete', 'statement', 'for', 'fact-checking', 'purposes.']
# My response is: No. This sentence does not contain a factual claim that can be checked. It is a statement about the intentions of unspecified people.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.', 'It', 'is', 'a', 'statement', 'about', 'the', 'intentions', 'of', 'unspecified', 'people.']
# My response is: Yes. This statement seems to be making a claim about the amount of money being paid in taxes, which could be fact-checked.
# ['My', 'response', 'is:', 'Yes.', 'This', 'statement', 'seems', 'to', 'be', 'making', 'a', 'claim', 'about', 'the', 'amount', 'of', 'money', 'being', 'paid', 'in', 'taxes,', 'which', 'could', 'be', 'fact-checked.']
# My response is: Yes. The sentence seems to be making a claim about the amount of money paid in two different years, which could be fact-checked.
# ['My', 'response', 'is:', 'Yes.', 'The', 'sentence', 'seems', 'to', 'be', 'making', 'a', 'claim', 'about', 'the', 'amount', 'of', 'money', 'paid', 'in', 'two', 'different', 'years,', 'which', 'could', 'be', 'fact-checked.']
# My response is: No, this sentence does not contain a fact-check worthy statement. It appears to be a fragment of speech, possibly indicating that Chris is asking for permission to speak about something related to the tax law.
# ['My', 'response', 'is:', 'No,', 'this', 'sentence', 'does', 'not', 'contain', 'a', 'fact-check', 'worthy', 'statement.', 'It', 'appears', 'to', 'be', 'a', 'fragment', 'of', 'speech,', 'possibly', 'indicating', 'that', 'Chris', 'is', 'asking', 'for', 'permission', 'to', 'speak', 'about', 'something', 'related', 'to', 'the', 'tax', 'law.']
# My response is: No. This statement does not contain a factual claim that can be checked. It is a statement of personal opinion or desire, and does not make a claim that can be verified or falsified.
# ['My', 'response', 'is:', 'No.', 'This', 'statement', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.', 'It', 'is', 'a', 'statement', 'of', 'personal', 'opinion', 'or', 'desire,', 'and', 'does', 'not', 'make', 'a', 'claim', 'that', 'can', 'be', 'verified', 'or', 'falsified.']
# My response is: No. This sentence does not contain a factual claim that can be checked. It is a statement about an action someone intends to take.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.', 'It', 'is', 'a', 'statement', 'about', 'an', 'action', 'someone', 'intends', 'to', 'take.']
# My response is: Yes. This statement does not contain any specific factual claims that can be easily checked, but it is a call to action that implies the importance of investing in certain people who are in need. However, the factuality of any subsequent actions or investments discussed in the context where this statement is made would be fact-check worthy.
# ['My', 'response', 'is:', 'Yes.', 'This', 'statement', 'does', 'not', 'contain', 'any', 'specific', 'factual', 'claims', 'that', 'can', 'be', 'easily', 'checked,', 'but', 'it', 'is', 'a', 'call', 'to', 'action', 'that', 'implies', 'the', 'importance', 'of', 'investing', 'in', 'certain', 'people', 'who', 'are', 'in', 'need.', 'However,', 'the', 'factuality', 'of', 'any', 'subsequent', 'actions', 'or', 'investments', 'discussed', 'in', 'the', 'context', 'where', 'this', 'statement', 'is', 'made', 'would', 'be', 'fact-check', 'worthy.']
# My response is: Yes, this statement could be fact-check worthy depending on the context in which it was made during a political debate or tweet. The lack of specificity regarding what "it" refers to makes it difficult to determine factual accuracy without additional context.
# ['My', 'response', 'is:', 'Yes,', 'this', 'statement', 'could', 'be', 'fact-check', 'worthy', 'depending', 'on', 'the', 'context', 'in', 'which', 'it', 'was', 'made', 'during', 'a', 'political', 'debate', 'or', 'tweet.', 'The', 'lack', 'of', 'specificity', 'regarding', 'what', '"it"', 'refers', 'to', 'makes', 'it', 'difficult', 'to', 'determine', 'factual', 'accuracy', 'without', 'additional', 'context.']
# My response is: Yes, this sentence could potentially contain a factually inaccurate or misleading statement, making it fact-check worthy. The use of vague language and the implied suggestion that something unusual or unethical has been done increases the likelihood that a fact check is necessary.
# ['My', 'response', 'is:', 'Yes,', 'this', 'sentence', 'could', 'potentially', 'contain', 'a', 'factually', 'inaccurate', 'or', 'misleading', 'statement,', 'making', 'it', 'fact-check', 'worthy.', 'The', 'use', 'of', 'vague', 'language', 'and', 'the', 'implied', 'suggestion', 'that', 'something', 'unusual', 'or', 'unethical', 'has', 'been', 'done', 'increases', 'the', 'likelihood', 'that', 'a', 'fact', 'check', 'is', 'necessary.']
# My response is: yes. This sentence seems to imply a specific policy proposal, and it may be important to fact-check the details of that proposal, such as how every penny is supposed to be made and by whom.
# ['My', 'response', 'is:', 'yes.', 'This', 'sentence', 'seems', 'to', 'imply', 'a', 'specific', 'policy', 'proposal,', 'and', 'it', 'may', 'be', 'important', 'to', 'fact-check', 'the', 'details', 'of', 'that', 'proposal,', 'such', 'as', 'how', 'every', 'penny', 'is', 'supposed', 'to', 'be', 'made', 'and', 'by', 'whom.']
# My response is: I cannot predict that with certainty based on the given sentence alone. The sentence does not provide enough context or information to determine if it is a fact check-worthy statement.
# ['My', 'response', 'is:', 'I', 'cannot', 'predict', 'that', 'with', 'certainty', 'based', 'on', 'the', 'given', 'sentence', 'alone.', 'The', 'sentence', 'does', 'not', 'provide', 'enough', 'context', 'or', 'information', 'to', 'determine', 'if', 'it', 'is', 'a', 'fact', 'check-worthy', 'statement.']
# My response is: I cannot predict that with certainty based on the given sentence alone. The sentence does not provide enough context or information to determine if it is a fact check-worthy statement.
# i
#
# My response is: No. This sentence does not contain a factual statement that can be checked. It is a fragment of a sentence in the future tense, expressing an intention or plan to act.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'statement', 'that', 'can', 'be', 'checked.', 'It', 'is', 'a', 'fragment', 'of', 'a', 'sentence', 'in', 'the', 'future', 'tense,', 'expressing', 'an', 'intention', 'or', 'plan', 'to', 'act.']
# My response is: no. The sentence does not make a fact-checkable statement. It is an opinion that does not have a verifiable fact behind it. The statement does not provide specific information about which economy is being referred to, or what metrics are being used to measure the economic recovery. Therefore, it cannot be fact-checked accurately.
# ['My', 'response', 'is:', 'no.', 'The', 'sentence', 'does', 'not', 'make', 'a', 'fact-checkable', 'statement.', 'It', 'is', 'an', 'opinion', 'that', 'does', 'not', 'have', 'a', 'verifiable', 'fact', 'behind', 'it.', 'The', 'statement', 'does', 'not', 'provide', 'specific', 'information', 'about', 'which', 'economy', 'is', 'being', 'referred', 'to,', 'or', 'what', 'metrics', 'are', 'being', 'used', 'to', 'measure', 'the', 'economic', 'recovery.', 'Therefore,', 'it', 'cannot', 'be', 'fact-checked', 'accurately.']
# My response is: No. This sentence does not contain a factual claim that can be checked. It appears to be a hypothetical statement about potential actions or policies, and does not contain any verifiable information.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.', 'It', 'appears', 'to', 'be', 'a', 'hypothetical', 'statement', 'about', 'potential', 'actions', 'or', 'policies,', 'and', 'does', 'not', 'contain', 'any', 'verifiable', 'information.']
# My response is: Yes, this statement could be fact-check worthy depending on the context. It is vague and could potentially be true or false, depending on the specific companies being referred to and why they are leaving or staying in a particular place.
# ['My', 'response', 'is:', 'Yes,', 'this', 'statement', 'could', 'be', 'fact-check', 'worthy', 'depending', 'on', 'the', 'context.', 'It', 'is', 'vague', 'and', 'could', 'potentially', 'be', 'true', 'or', 'false,', 'depending', 'on', 'the', 'specific', 'companies', 'being', 'referred', 'to', 'and', 'why', 'they', 'are', 'leaving', 'or', 'staying', 'in', 'a', 'particular', 'place.']
# My response is: No. The sentence does not contain a factual statement that can be checked. It appears to be nonsensical or metaphorical in nature.
# ['My', 'response', 'is:', 'No.', 'The', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'statement', 'that', 'can', 'be', 'checked.', 'It', 'appears', 'to', 'be', 'nonsensical', 'or', 'metaphorical', 'in', 'nature.']
# My response is: Yes, such a statement could be fact-check worthy depending on the context in which it was made, as the number of jobs brought back would need to be verifiable.
# ['My', 'response', 'is:', 'Yes,', 'such', 'a', 'statement', 'could', 'be', 'fact-check', 'worthy', 'depending', 'on', 'the', 'context', 'in', 'which', 'it', 'was', 'made,', 'as', 'the', 'number', 'of', 'jobs', 'brought', 'back', 'would', 'need', 'to', 'be', 'verifiable.']
# My response is: yes. The sentence implies a comparison between the current deficit with China and one in the past, making it fact check-worthy.
# ['My', 'response', 'is:', 'yes.', 'The', 'sentence', 'implies', 'a', 'comparison', 'between', 'the', 'current', 'deficit', 'with', 'China', 'and', 'one', 'in', 'the', 'past,', 'making', 'it', 'fact', 'check-worthy.']
# My response is: Yes, this sentence could be fact-check worthy depending on the context. It seems incomplete and could potentially be referring to a specific action or policy that someone has taken, and the speaker may be implying that this action or policy warrants a certain consequence. Without more context, it's difficult to say for sure what is being referred to, but it's possible that the statement could be misleading or inaccurate if taken out of context.
# ['My', 'response', 'is:', 'Yes,', 'this', 'sentence', 'could', 'be', 'fact-check', 'worthy', 'depending', 'on', 'the', 'context.', 'It', 'seems', 'incomplete', 'and', 'could', 'potentially', 'be', 'referring', 'to', 'a', 'specific', 'action', 'or', 'policy', 'that', 'someone', 'has', 'taken,', 'and', 'the', 'speaker', 'may', 'be', 'implying', 'that', 'this', 'action', 'or', 'policy', 'warrants', 'a', 'certain', 'consequence.', 'Without', 'more', 'context,', "it's", 'difficult', 'to', 'say', 'for', 'sure', 'what', 'is', 'being', 'referred', 'to,', 'but', "it's", 'possible', 'that', 'the', 'statement', 'could', 'be', 'misleading', 'or', 'inaccurate', 'if', 'taken', 'out', 'of', 'context.']
# My response is: Yes, this statement could be fact-check worthy depending on the specific context and who "some people" refers to.
# ['My', 'response', 'is:', 'Yes,', 'this', 'statement', 'could', 'be', 'fact-check', 'worthy', 'depending', 'on', 'the', 'specific', 'context', 'and', 'who', '"some', 'people"', 'refers', 'to.']
# My response is: no. This sentence does not contain a factual statement that can be checked. It appears to simply express a desire or topic for discussion.
# ['My', 'response', 'is:', 'no.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'statement', 'that', 'can', 'be', 'checked.', 'It', 'appears', 'to', 'simply', 'express', 'a', 'desire', 'or', 'topic', 'for', 'discussion.']
# My response is: yes. This statement implies that the use of tear gas by the military was done specifically for the president to walk to a church, which is a factual claim that could be checked.
# ['My', 'response', 'is:', 'yes.', 'This', 'statement', 'implies', 'that', 'the', 'use', 'of', 'tear', 'gas', 'by', 'the', 'military', 'was', 'done', 'specifically', 'for', 'the', 'president', 'to', 'walk', 'to', 'a', 'church,', 'which', 'is', 'a', 'factual', 'claim', 'that', 'could', 'be', 'checked.']
# My response is: No. This sentence does not contain a factual claim that can be checked.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.']
# My response is: yes. This statement seems to imply that the actions or words of a specific general have been divisive rather than unifying, which is a claim that could potentially be fact-checked.
# ['My', 'response', 'is:', 'yes.', 'This', 'statement', 'seems', 'to', 'imply', 'that', 'the', 'actions', 'or', 'words', 'of', 'a', 'specific', 'general', 'have', 'been', 'divisive', 'rather', 'than', 'unifying,', 'which', 'is', 'a', 'claim', 'that', 'could', 'potentially', 'be', 'fact-checked.']
# My response is: No. This sentence does not contain a factual statement that can be checked. It appears to be fragmented and unclear in meaning.
# ...
# ['My', 'response', 'is:', 'Yes,', 'this', 'statement', 'could', 'be', 'fact-check', 'worthy', 'depending', 'on', 'the', 'context.', 'For', 'example,', 'it', 'could', 'be', 'a', 'call', 'for', 'mandatory', 'treatment', 'for', 'certain', 'issues,', 'which', 'would', 'require', 'fact-checking', 'to', 'determine', 'the', 'specifics', 'and', 'potential', 'implications.']
# My response is: No. This sentence does not contain a factual claim that can be checked.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.']
# My response is: no. This sentence appears to be incomplete and grammatically incorrect, making it difficult to determine if it is a factual statement or not.
# ['My', 'response', 'is:', 'no.', 'This', 'sentence', 'appears', 'to', 'be', 'incomplete', 'and', 'grammatically', 'incorrect,', 'making', 'it', 'difficult', 'to', 'determine', 'if', 'it', 'is', 'a', 'factual', 'statement', 'or', 'not.']
# My response is: yes. The number given in the sentence suggests a factual statement, even if it may be incomplete or missing context. However, it is important to note that the accuracy of this statement would depend on whether or not the information is coming from a reliable source and if there are any additional context or details that may affect the truthfulness of this statement.
# ['My', 'response', 'is:', 'yes.', 'The', 'number', 'given', 'in', 'the', 'sentence', 'suggests', 'a', 'factual', 'statement,', 'even', 'if', 'it', 'may', 'be', 'incomplete', 'or', 'missing', 'context.', 'However,', 'it', 'is', 'important', 'to', 'note', 'that', 'the', 'accuracy', 'of', 'this', 'statement', 'would', 'depend', 'on', 'whether', 'or', 'not', 'the', 'information', 'is', 'coming', 'from', 'a', 'reliable', 'source', 'and', 'if', 'there', 'are', 'any', 'additional', 'context', 'or', 'details', 'that', 'may', 'affect', 'the', 'truthfulness', 'of', 'this', 'statement.']
# My response is: I cannot determine without additional context. The sentence seems incomplete and lacks specificity to make a fact-checkable statement.
# ['My', 'response', 'is:', 'I', 'cannot', 'determine', 'without', 'additional', 'context.', 'The', 'sentence', 'seems', 'incomplete', 'and', 'lacks', 'specificity', 'to', 'make', 'a', 'fact-checkable', 'statement.']
# My response is: I cannot determine without additional context. The sentence seems incomplete and lacks specificity to make a fact-checkable statement.
# i
#
# My response is: yes. This statement could potentially be fact-check worthy as it makes a quantifiable claim about the demographic composition of individuals put in prison. However, it's important to note that the accuracy of this claim would depend on reliable and up-to-date data from credible sources.
# ['My', 'response', 'is:', 'yes.', 'This', 'statement', 'could', 'potentially', 'be', 'fact-check', 'worthy', 'as', 'it', 'makes', 'a', 'quantifiable', 'claim', 'about', 'the', 'demographic', 'composition', 'of', 'individuals', 'put', 'in', 'prison.', 'However,', "it's", 'important', 'to', 'note', 'that', 'the', 'accuracy', 'of', 'this', 'claim', 'would', 'depend', 'on', 'reliable', 'and', 'up-to-date', 'data', 'from', 'credible', 'sources.']
# My response is: No. This statement appears to be a personal attack rather than making a factual claim that can be checked.
# ['My', 'response', 'is:', 'No.', 'This', 'statement', 'appears', 'to', 'be', 'a', 'personal', 'attack', 'rather', 'than', 'making', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.']
# My response is: No. This sentence does not contain a factual claim that can be checked. It is a colloquial expression that means trying to persuade someone to agree with you.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.', 'It', 'is', 'a', 'colloquial', 'expression', 'that', 'means', 'trying', 'to', 'persuade', 'someone', 'to', 'agree', 'with', 'you.']
# My response is: no. The sentence does not contain a factual claim that can be checked. It is a subjective statement about an observation of the speaker.
# ['My', 'response', 'is:', 'no.', 'The', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.', 'It', 'is', 'a', 'subjective', 'statement', 'about', 'an', 'observation', 'of', 'the', 'speaker.']
# My response is: yes, this statement could be fact-checked as it contains a quantifiable claim about the potential impact of an agreement on jobs and companies.
# ['My', 'response', 'is:', 'yes,', 'this', 'statement', 'could', 'be', 'fact-checked', 'as', 'it', 'contains', 'a', 'quantifiable', 'claim', 'about', 'the', 'potential', 'impact', 'of', 'an', 'agreement', 'on', 'jobs', 'and', 'companies.']
# My response is: Yes, this statement does not provide enough context to determine if it is factual or not, but it does express a moral belief. Therefore, while not fact check-worthy in the strict sense, it may still be subject to debate or discussion regarding the specific issue being referred to.
# ['My', 'response', 'is:', 'Yes,', 'this', 'statement', 'does', 'not', 'provide', 'enough', 'context', 'to', 'determine', 'if', 'it', 'is', 'factual', 'or', 'not,', 'but', 'it', 'does', 'express', 'a', 'moral', 'belief.', 'Therefore,', 'while', 'not', 'fact', 'check-worthy', 'in', 'the', 'strict', 'sense,', 'it', 'may', 'still', 'be', 'subject', 'to', 'debate', 'or', 'discussion', 'regarding', 'the', 'specific', 'issue', 'being', 'referred', 'to.']
# My response is: yes. This sentence appears to contain multiple potential factual claims that could be checked. For example, the number of buildings and homes to be retrofitted, the amount of oil that could be saved, and the number of jobs created.
# ['My', 'response', 'is:', 'yes.', 'This', 'sentence', 'appears', 'to', 'contain', 'multiple', 'potential', 'factual', 'claims', 'that', 'could', 'be', 'checked.', 'For', 'example,', 'the', 'number', 'of', 'buildings', 'and', 'homes', 'to', 'be', 'retrofitted,', 'the', 'amount', 'of', 'oil', 'that', 'could', 'be', 'saved,', 'and', 'the', 'number', 'of', 'jobs', 'created.']
# My response is: yes. This statement implies a specific number (6500) being taken away from families under a certain plan, which could potentially be fact-checked to determine its accuracy.
# ['My', 'response', 'is:', 'yes.', 'This', 'statement', 'implies', 'a', 'specific', 'number', '(6500)', 'being', 'taken', 'away', 'from', 'families', 'under', 'a', 'certain', 'plan,', 'which', 'could', 'potentially', 'be', 'fact-checked', 'to', 'determine', 'its', 'accuracy.']
# My response is: yes. The statement seems to be making a claim about the cost of someone or something's plan being 100 trillion dollars, which is a specific numerical amount and therefore fact-check worthy.
# ['My', 'response', 'is:', 'yes.', 'The', 'statement', 'seems', 'to', 'be', 'making', 'a', 'claim', 'about', 'the', 'cost', 'of', 'someone', 'or', "something's", 'plan', 'being', '100', 'trillion', 'dollars,', 'which', 'is', 'a', 'specific', 'numerical', 'amount', 'and', 'therefore', 'fact-check', 'worthy.']
# My response is: no. This sentence appears to be a misspelled and grammatically incorrect statement, rather than a factual claim. It does not contain any verifiable information that could be fact-checked.
# ['My', 'response', 'is:', 'no.', 'This', 'sentence', 'appears', 'to', 'be', 'a', 'misspelled', 'and', 'grammatically', 'incorrect', 'statement,', 'rather', 'than', 'a', 'factual', 'claim.', 'It', 'does', 'not', 'contain', 'any', 'verifiable', 'information', 'that', 'could', 'be', 'fact-checked.']
# My response is: Yes, this statement could be fact-check worthy depending on the context and specific meaning of "energy independent." If the speaker means that the country as a whole produces more energy than it consumes, then this could be a factual statement. However, if the speaker means something else, such as achieving energy security or reducing reliance on specific types of fuel, then the statement may require further context or fact-checking.
# ['My', 'response', 'is:', 'Yes,', 'this', 'statement', 'could', 'be', 'fact-check', 'worthy', 'depending', 'on', 'the', 'context', 'and', 'specific', 'meaning', 'of', '"energy', 'independent."', 'If', 'the', 'speaker', 'means', 'that', 'the', 'country', 'as', 'a', 'whole', 'produces', 'more', 'energy', 'than', 'it', 'consumes,', 'then', 'this', 'could', 'be', 'a', 'factual', 'statement.', 'However,', 'if', 'the', 'speaker', 'means', 'something', 'else,', 'such', 'as', 'achieving', 'energy', 'security', 'or', 'reducing', 'reliance', 'on', 'specific', 'types', 'of', 'fuel,', 'then', 'the', 'statement', 'may', 'require', 'further', 'context', 'or', 'fact-checking.']
# My response is: No. The sentence does not contain a factual claim that can be checked.
# ['My', 'response', 'is:', 'No.', 'The', 'sentence', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.']
# My response is: yes. This statement implies a causal relationship between getting rid of the oil industry and killing the economy, which is a factual claim that could be checked.
# ['My', 'response', 'is:', 'yes.', 'This', 'statement', 'implies', 'a', 'causal', 'relationship', 'between', 'getting', 'rid', 'of', 'the', 'oil', 'industry', 'and', 'killing', 'the', 'economy,', 'which', 'is', 'a', 'factual', 'claim', 'that', 'could', 'be', 'checked.']
# My response is: No. This sentence does not make a clear statement that can be fact-checked.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'does', 'not', 'make', 'a', 'clear', 'statement', 'that', 'can', 'be', 'fact-checked.']
# My response is: No. The sentence appears to be misspelled and grammatically incorrect, making it difficult to determine if it is a factual statement or not. However, based on the context provided in the sentence itself, it does not seem to be a statement that would typically require fact-checking.
# ['My', 'response', 'is:', 'No.', 'The', 'sentence', 'appears', 'to', 'be', 'misspelled', 'and', 'grammatically', 'incorrect,', 'making', 'it', 'difficult', 'to', 'determine', 'if', 'it', 'is', 'a', 'factual', 'statement', 'or', 'not.', 'However,', 'based', 'on', 'the', 'context', 'provided', 'in', 'the', 'sentence', 'itself,', 'it', 'does', 'not', 'seem', 'to', 'be', 'a', 'statement', 'that', 'would', 'typically', 'require', 'fact-checking.']
# My response is: Yes, this sentence seems fact-check worthy as it contains several quantitative claims that could potentially be checked for accuracy. However, it is important to note that the sentence appears to be incomplete and may require additional context or clarification to fully understand its meaning.
# ['My', 'response', 'is:', 'Yes,', 'this', 'sentence', 'seems', 'fact-check', 'worthy', 'as', 'it', 'contains', 'several', 'quantitative', 'claims', 'that', 'could', 'potentially', 'be', 'checked', 'for', 'accuracy.', 'However,', 'it', 'is', 'important', 'to', 'note', 'that', 'the', 'sentence', 'appears', 'to', 'be', 'incomplete', 'and', 'may', 'require', 'additional', 'context', 'or', 'clarification', 'to', 'fully', 'understand', 'its', 'meaning.']
# My response is: yes. This statement implies a causation between government actions and the current state of the oil industry, which is a claim that can be fact-checked.
# ['My', 'response', 'is:', 'yes.', 'This', 'statement', 'implies', 'a', 'causation', 'between', 'government', 'actions', 'and', 'the', 'current', 'state', 'of', 'the', 'oil', 'industry,', 'which', 'is', 'a', 'claim', 'that', 'can', 'be', 'fact-checked.']
# My response is: yes. This statement implies a current or proposed action to stop giving federal subsidies to the oil industry, which is a factual claim that could be checked.
# ['My', 'response', 'is:', 'yes.', 'This', 'statement', 'implies', 'a', 'current', 'or', 'proposed', 'action', 'to', 'stop', 'giving', 'federal', 'subsidies', 'to', 'the', 'oil', 'industry,', 'which', 'is', 'a', 'factual', 'claim', 'that', 'could', 'be', 'checked.']
# My response is: yes, this statement could be fact-check worthy depending on the context and specific policy being discussed.
# ['My', 'response', 'is:', 'yes,', 'this', 'statement', 'could', 'be', 'fact-check', 'worthy', 'depending', 'on', 'the', 'context', 'and', 'specific', 'policy', 'being', 'discussed.']
# My response is: yes. This statement implies a comparison of the country's state before and after the plague, suggesting a claim about its success or lack thereof during those two periods. Such a comparison could potentially involve factual information that is subject to verification.
# ['My', 'response', 'is:', 'yes.', 'This', 'statement', 'implies', 'a', 'comparison', 'of', 'the', "country's", 'state', 'before', 'and', 'after', 'the', 'plague,', 'suggesting', 'a', 'claim', 'about', 'its', 'success', 'or', 'lack', 'thereof', 'during', 'those', 'two', 'periods.', 'Such', 'a', 'comparison', 'could', 'potentially', 'involve', 'factual', 'information', 'that', 'is', 'subject', 'to', 'verification.']
# My response is: yes. This statement seems to be making a claim about current unemployment numbers for specific demographic groups, which could be fact-checked.
# ['My', 'response', 'is:', 'yes.', 'This', 'statement', 'seems', 'to', 'be', 'making', 'a', 'claim', 'about', 'current', 'unemployment', 'numbers', 'for', 'specific', 'demographic', 'groups,', 'which', 'could', 'be', 'fact-checked.']
# My response is: No. The sentence appears to be grammatically incorrect and does not contain a factual statement.
# ['My', 'response', 'is:', 'No.', 'The', 'sentence', 'appears', 'to', 'be', 'grammatically', 'incorrect', 'and', 'does', 'not', 'contain', 'a', 'factual', 'statement.']
# My response is: No. This sentence expresses an opinion and does not contain a factual claim that can be checked.
# ['My', 'response', 'is:', 'No.', 'This', 'sentence', 'expresses', 'an', 'opinion', 'and', 'does', 'not', 'contain', 'a', 'factual', 'claim', 'that', 'can', 'be', 'checked.']
# My response is: Yes, this sentence could be fact-check worthy depending on the context in which it was used during a political debate or tweet. The use of the word "enormous opportunity" could potentially be a subjective claim that requires factual evidence to support it.
# ['My', 'response', 'is:', 'Yes,', 'this', 'sentence', 'could', 'be', 'fact-check', 'worthy', 'depending', 'on', 'the', 'context', 'in', 'which', 'it', 'was', 'used', 'during', 'a', 'political', 'debate', 'or', 'tweet.', 'The', 'use', 'of', 'the', 'word', '"enormous', 'opportunity"', 'could', 'potentially', 'be', 'a', 'subjective', 'claim', 'that', 'requires', 'factual', 'evidence', 'to', 'support', 'it.']
# My response is: Yes, statements about growing the economy are often fact-check worthy as they can be made with various levels of specificity and accuracy. For example, some statements might refer to specific policies or actions that have been proposed or implemented, while others might be more general in nature. In each case, it's important to evaluate the evidence and context behind the claim in order to determine its factual accuracy.
# ['My', 'response', 'is:', 'Yes,', 'statements', 'about', 'growing', 'the', 'economy', 'are', 'often', 'fact-check', 'worthy', 'as', 'they', 'can', 'be', 'made', 'with', 'various', 'levels', 'of', 'specificity', 'and', 'accuracy.', 'For', 'example,', 'some', 'statements', 'might', 'refer', 'to', 'specific', 'policies', 'or', 'actions', 'that', 'have', 'been', 'proposed', 'or', 'implemented,', 'while', 'others', 'might', 'be', 'more', 'general', 'in', 'nature.', 'In', 'each', 'case,', "it's", 'important', 'to', 'evaluate', 'the', 'evidence', 'and', 'context', 'behind', 'the', 'claim', 'in', 'order', 'to', 'determine', 'its', 'factual', 'accuracy.']

# %%
for index, row in df.iterrows():
    if row['class_label'].lower() == listofpredicts[index]:
        similarity += 1
similarity_score = (similarity / len(listofpredicts)) * 100
print("Similarity mistral/dataset: ", similarity_score)
# Out:
# Similarity mistral/dataset:  59.43396226415094
