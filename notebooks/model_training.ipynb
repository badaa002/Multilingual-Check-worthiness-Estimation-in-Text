# %% [markdown]
# # File for training XML-RoBERTa on factchecking data

# %% [markdown]
# Installing libraries

# %%
import pandas as pd
import numpy as np
import torch
from datasets import Dataset
from sklearn.metrics import precision_recall_fscore_support, accuracy_score
from transformers import (
    AutoModelForSequenceClassification,
    AutoTokenizer,
    EvalPrediction,
    Trainer,
    TrainingArguments,
)
import wandb
import os
from sklearn.utils import shuffle
from typing import Any

# %% [markdown]
# # Creating a new folder to save data to after each run

# %%
def get_paths(is_gdrive: bool = False) -> Any:
    """Get paths for training data and storing results.

    Args:
        is_gdrive: Whether to use Google Drive path for storing results and
            retrieving data.

    Returns:
        dataset_path: Path to training data.
        save_path: Path to store results.
    """
    dataset_path = (
        "./drive/MyDrive/data"
        if is_gdrive
        else "/home/emrds/repos/Multilingual-Check-worthiness-Estimation-in-Text/data/processed/"
    )
    save_folder = (
        "./drive/MyDrive/results"
        if is_gdrive
        else "/home/emrds/repos/Multilingual-Check-worthiness-Estimation-in-Text/results"
    )

    folders = os.listdir(save_folder)
    run_numbers = [int(folder[3:]) for folder in folders if folder.startswith("run")]
    run_id = max(run_numbers, default=0) + 1

    save_path = f"{save_folder}/run{run_id}"

    os.makedirs(save_path)
    return dataset_path, save_path

# %%
def load_dataset(path: str) -> Dataset:
    df = pd.read_csv(path, sep="\t")
    df = df.copy()

    dataset = Dataset.from_pandas(df)
    return dataset

# %%
tokenizer = AutoTokenizer.from_pretrained("xlm-roberta-large")

# %%
def tokenize_function(examples):
    return tokenizer(
        examples["text"], padding="max_length", truncation=True, max_length=512
    )

# %%
dataset_path, save_path = get_paths(is_gdrive=False)

train_dataset = load_dataset(f"{dataset_path}/merged_train.tsv")
test_dataset = load_dataset(f"{dataset_path}/merged_test.tsv")
dev_test_dataset = load_dataset(f"{dataset_path}/merged_dev_test.tsv")

tokenized_train_dataset = train_dataset.map(tokenize_function, batched=True)
tokenized_test_dataset = test_dataset.map(tokenize_function, batched=True)
# tokenized_dev_test_dataset = dev_test_dataset.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/50763 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7377 [00:00<?, ? examples/s]
# Map:   0%|          | 0/6484 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 9
#       7 tokenized_train_dataset = train_dataset.map(tokenize_function, batched=True)
#       8 tokenized_test_dataset = test_dataset.map(tokenize_function, batched=True)
# ----> 9 tokenized_dev_test_dataset = dev_test_dataset.map(tokenize_function, batched=True)
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/datasets/arrow_dataset.py:593, in transmit_tasks.<locals>.wrapper(*args, **kwargs)
#     591     self: "Dataset" = kwargs.pop("self")
#     592 # apply actual function
# --> 593 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     594 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     595 for dataset in datasets:
#     596     # Remove task templates if a column mapping of the template is no longer valid
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/datasets/arrow_dataset.py:558, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     551 self_format = {
#     552     "type": self._format_type,
#     553     "format_kwargs": self._format_kwargs,
#     554     "columns": self._format_columns,
#     555     "output_all_columns": self._output_all_columns,
#     556 }
#     557 # apply actual function
# --> 558 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     559 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     560 # re-apply format to the output
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/datasets/arrow_dataset.py:3105, in Dataset.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc)
#    3099 if transformed_dataset is None:
#    3100     with hf_tqdm(
#    3101         unit=" examples",
#    3102         total=pbar_total,
#    3103         desc=desc or "Map",
#    3104     ) as pbar:
# -> 3105         for rank, done, content in Dataset._map_single(**dataset_kwargs):
#    3106             if done:
#    3107                 shards_done += 1
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/datasets/arrow_dataset.py:3482, in Dataset._map_single(shard, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, new_fingerprint, rank, offset)
#    3478 indices = list(
#    3479     range(*(slice(i, i + batch_size).indices(shard.num_rows)))
#    3480 )  # Something simpler?
#    3481 try:
# -> 3482     batch = apply_function_on_filtered_inputs(
#    3483         batch,
#    3484         indices,
#    3485         check_same_num_examples=len(shard.list_indexes()) > 0,
#    3486         offset=offset,
#    3487     )
#    3488 except NumExamplesMismatchError:
#    3489     raise DatasetTransformationNotAllowedError(
#    3490         "Using `.map` in batched mode on a dataset with attached indexes is allowed only if it doesn't create or remove existing examples. You can first run `.drop_index() to remove your index and then re-add it."
#    3491     ) from None
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/datasets/arrow_dataset.py:3361, in Dataset._map_single.<locals>.apply_function_on_filtered_inputs(pa_inputs, indices, check_same_num_examples, offset)
#    3359 if with_rank:
#    3360     additional_args += (rank,)
# -> 3361 processed_inputs = function(*fn_args, *additional_args, **fn_kwargs)
#    3362 if isinstance(processed_inputs, LazyDict):
#    3363     processed_inputs = {
#    3364         k: v for k, v in processed_inputs.data.items() if k not in processed_inputs.keys_to_format
#    3365     }
#
# Cell In[25], line 2, in tokenize_function(examples)
#       1 def tokenize_function(examples):
# ----> 2     return tokenizer(
#       3         examples["text"], padding="max_length", truncation=True, max_length=512
#       4     )
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:2872, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2870     if not self._in_target_context_manager:
#    2871         self._switch_to_input_mode()
# -> 2872     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    2873 if text_target is not None:
#    2874     self._switch_to_target_mode()
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:2958, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2953         raise ValueError(
#    2954             f"batch length of `text`: {len(text)} does not match batch length of `text_pair`:"
#    2955             f" {len(text_pair)}."
#    2956         )
#    2957     batch_text_or_text_pairs = list(zip(text, text_pair)) if text_pair is not None else text
# -> 2958     return self.batch_encode_plus(
#    2959         batch_text_or_text_pairs=batch_text_or_text_pairs,
#    2960         add_special_tokens=add_special_tokens,
#    2961         padding=padding,
#    2962         truncation=truncation,
#    2963         max_length=max_length,
#    2964         stride=stride,
#    2965         is_split_into_words=is_split_into_words,
#    2966         pad_to_multiple_of=pad_to_multiple_of,
#    2967         return_tensors=return_tensors,
#    2968         return_token_type_ids=return_token_type_ids,
#    2969         return_attention_mask=return_attention_mask,
#    2970         return_overflowing_tokens=return_overflowing_tokens,
#    2971         return_special_tokens_mask=return_special_tokens_mask,
#    2972         return_offsets_mapping=return_offsets_mapping,
#    2973         return_length=return_length,
#    2974         verbose=verbose,
#    2975         **kwargs,
#    2976     )
#    2977 else:
#    2978     return self.encode_plus(
#    2979         text=text,
#    2980         text_pair=text_pair,
#    (...)
#    2996         **kwargs,
#    2997     )
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:3149, in PreTrainedTokenizerBase.batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    3139 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
#    3140 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    3141     padding=padding,
#    3142     truncation=truncation,
#    (...)
#    3146     **kwargs,
#    3147 )
# -> 3149 return self._batch_encode_plus(
#    3150     batch_text_or_text_pairs=batch_text_or_text_pairs,
#    3151     add_special_tokens=add_special_tokens,
#    3152     padding_strategy=padding_strategy,
#    3153     truncation_strategy=truncation_strategy,
#    3154     max_length=max_length,
#    3155     stride=stride,
#    3156     is_split_into_words=is_split_into_words,
#    3157     pad_to_multiple_of=pad_to_multiple_of,
#    3158     return_tensors=return_tensors,
#    3159     return_token_type_ids=return_token_type_ids,
#    3160     return_attention_mask=return_attention_mask,
#    3161     return_overflowing_tokens=return_overflowing_tokens,
#    3162     return_special_tokens_mask=return_special_tokens_mask,
#    3163     return_offsets_mapping=return_offsets_mapping,
#    3164     return_length=return_length,
#    3165     verbose=verbose,
#    3166     **kwargs,
#    3167 )
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/transformers/tokenization_utils_fast.py:504, in PreTrainedTokenizerFast._batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose)
#     495 # Set the truncation and padding strategy and restore the initial configuration
#     496 self.set_truncation_and_padding(
#     497     padding_strategy=padding_strategy,
#     498     truncation_strategy=truncation_strategy,
#    (...)
#     501     pad_to_multiple_of=pad_to_multiple_of,
#     502 )
# --> 504 encodings = self._tokenizer.encode_batch(
#     505     batch_text_or_text_pairs,
#     506     add_special_tokens=add_special_tokens,
#     507     is_pretokenized=is_split_into_words,
#     508 )
#     510 # Convert encoding to dict
#     511 # `Tokens` has type: Tuple[
#     512 #                       List[Dict[str, List[List[int]]]] or List[Dict[str, 2D-Tensor]],
#     513 #                       List[EncodingFast]
#     514 #                    ]
#     515 # with nested dimensions corresponding to batch, overflows, sequence length
#     516 tokens_and_encodings = [
#     517     self._convert_encoding(
#     518         encoding=encoding,
#    (...)
#     527     for encoding in encodings
#     528 ]
#
# TypeError: TextEncodeInput must be Union[TextInputSequence, Tuple[InputSequence, InputSequence]]

# %%
train_dataset
# Out:
# Dataset({
#     features: ['text', 'label', 'text_length', 'hashtags', 'mentions', 'text_length_category', 'hashtags_frequency', 'hashtags_sentiment', 'hashtags_topics'],
#     num_rows: 50763
# })
